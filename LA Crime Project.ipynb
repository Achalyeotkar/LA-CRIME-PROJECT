# %%
import pandas as pd
import matplotlib.pyplot as plt
crime=pd.read_csv("C:\data sets/Crime_Data_from_2020_to_Present.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19920\231310075.py:3: SyntaxWarning: invalid escape sequence '\d'
#   crime=pd.read_csv("C:\data sets/Crime_Data_from_2020_to_Present.csv")

# %%
crime
# Out:
#         division_number date_reported     date_occurred  area    area_name  \
# 0              10304468    08-01-2020  08-01-2020 22:30     3    Southwest
# 1             190101086    02-01-2020  01-01-2020 03:30     1      Central
# 2             200110444    14-04-2020  13-02-2020 12:00     1      Central
# 3             191501505    01-01-2020  01-01-2020 17:30    15  N Hollywood
# 4             191921269    01-01-2020  01-01-2020 04:15    19      Mission
# ...                 ...           ...               ...   ...          ...
# 852945        231606525    22-03-2023  22-03-2023 10:00    16     Foothill
# 852946        231210064    12-04-2023  12-04-2023 16:30    12  77th Street
# 852947        230115220    02-07-2023  01-07-2023 00:01     1      Central
# 852948        230906458    05-03-2023  05-03-2023 09:00     9     Van Nuys
# 852949        230319786    10-11-2023  09-11-2023 23:00     3    Southwest
#
#         reporting_district  part  crime_code  \
# ...

# %%
crime.head()
# Out:
#    division_number date_reported     date_occurred  area    area_name  \
# 0         10304468    08-01-2020  08-01-2020 22:30     3    Southwest
# 1        190101086    02-01-2020  01-01-2020 03:30     1      Central
# 2        200110444    14-04-2020  13-02-2020 12:00     1      Central
# 3        191501505    01-01-2020  01-01-2020 17:30    15  N Hollywood
# 4        191921269    01-01-2020  01-01-2020 04:15    19      Mission
#
#    reporting_district  part  crime_code  \
# 0                 377     2         624
# 1                 163     2         624
# 2                 155     2         845
# 3                1543     2         745
# 4                1998     2         740
#
#                                    crime_description  modus_operandi  ...  \
# 0                           BATTERY - SIMPLE ASSAULT       0444 0913  ...
# 1                           BATTERY - SIMPLE ASSAULT  0416 1822 1414  ...
# ...

# %%
crime.columns
# Out:
# Index(['division_number', 'date_reported', 'date_occurred', 'area',
#        'area_name', 'reporting_district', 'part', 'crime_code',
#        'crime_description', 'modus_operandi', 'victim_age', 'victim_sex',
#        'victim_descent', 'premise_code', 'premise_description', 'weapon_code',
#        'weapon_description', 'status', 'status_description', 'crime_code_1',
#        'crime_code_2', 'crime_code_3', 'crime_code_4', 'location',
#        'cross_street', 'latitude', 'longitude'],
#       dtype='object')

# %%
crime.shape
# Out:
# (852950, 27)

# %%
crime.dtypes
# Out:
# division_number          int64
# date_reported           object
# date_occurred           object
# area                     int64
# area_name               object
# reporting_district       int64
# part                     int64
# crime_code               int64
# crime_description       object
# modus_operandi          object
# victim_age               int64
# victim_sex              object
# victim_descent          object
# premise_code           float64
# premise_description     object
# weapon_code            float64
# weapon_description      object
# status                  object
# status_description      object
# crime_code_1           float64
# crime_code_2           float64
# crime_code_3           float64
# crime_code_4           float64
# location                object
# cross_street            object
# latitude               float64
# longitude              float64
# dtype: object

# %%
#Check Nulls
crime.isna().sum()
# Out:
# division_number             0
# date_reported               0
# date_occurred               0
# area                        0
# area_name                   0
# reporting_district          0
# part                        0
# crime_code                  0
# crime_description           0
# modus_operandi         118311
# victim_age                  0
# victim_sex             112606
# victim_descent         112614
# premise_code               10
# premise_description       518
# weapon_code            556202
# weapon_description     556202
# status                      0
# status_description          0
# crime_code_1               11
# crime_code_2           790429
# crime_code_3           850837
# crime_code_4           852888
# location                    0
# cross_street           717289
# latitude                    0
# longitude                   0
# dtype: int64

# %%
df=crime.drop(labels=['modus_operandi', 'victim_sex,victim_descent', 'premise_code,premise_description', 'weapon_description', 'crime_code_1', 
                      'crime_code_2', 'crime_code_3', 'crime_code_4', 'cross_street'], axis=1, errors='ignore')
df
# Out:
#         division_number date_reported     date_occurred  area    area_name  \
# 0              10304468    08-01-2020  08-01-2020 22:30     3    Southwest
# 1             190101086    02-01-2020  01-01-2020 03:30     1      Central
# 2             200110444    14-04-2020  13-02-2020 12:00     1      Central
# 3             191501505    01-01-2020  01-01-2020 17:30    15  N Hollywood
# 4             191921269    01-01-2020  01-01-2020 04:15    19      Mission
# ...                 ...           ...               ...   ...          ...
# 852945        231606525    22-03-2023  22-03-2023 10:00    16     Foothill
# 852946        231210064    12-04-2023  12-04-2023 16:30    12  77th Street
# 852947        230115220    02-07-2023  01-07-2023 00:01     1      Central
# 852948        230906458    05-03-2023  05-03-2023 09:00     9     Van Nuys
# 852949        230319786    10-11-2023  09-11-2023 23:00     3    Southwest
#
#         reporting_district  part  crime_code  \
# ...

# %%
df.sort_values(by='date_reported')
# Out:
#         division_number date_reported     date_occurred  area    area_name  \
# 147992        202104014    01-01-2020  01-01-2020 17:10    21      Topanga
# 4438          200504035    01-01-2020  01-01-2020 04:30     5       Harbor
# 4437          200504032    01-01-2020  01-01-2020 04:00     5       Harbor
# 4436          200504021    01-01-2020  01-01-2020 19:30     5       Harbor
# 43722         200904016    01-01-2020  01-01-2020 01:00     9     Van Nuys
# ...                 ...           ...               ...   ...          ...
# 479499        221822958    31-12-2022  27-12-2022 18:00    18    Southeast
# 529525        220416827    31-12-2022  23-12-2022 12:00     4   Hollenbeck
# 504960        231604001    31-12-2022  25-12-2022 00:01    16     Foothill
# 608890        221001027    31-12-2022  31-12-2022 12:50    10  West Valley
# 412860        221226255    31-12-2022  30-12-2022 16:00    12  77th Street
#
#         reporting_district  part  crime_code  \
# ...

# %%
df.dtypes
# Out:
# division_number          int64
# date_reported           object
# date_occurred           object
# area                     int64
# area_name               object
# reporting_district       int64
# part                     int64
# crime_code               int64
# crime_description       object
# victim_age               int64
# victim_sex              object
# victim_descent          object
# premise_code           float64
# premise_description     object
# weapon_code            float64
# status                  object
# status_description      object
# location                object
# latitude               float64
# longitude              float64
# dtype: object

# %%
df['date_reported'] = pd.to_datetime(df['date_reported'], errors='coerce')
df['date_occurred'] = pd.to_datetime(df['date_occurred'], errors='coerce')

# %%
df
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-08-01 2020-08-01 22:30:00     3    Southwest
# 1             190101086    2020-02-01 2020-01-01 03:30:00     1      Central
# 2             200110444           NaT                 NaT     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525           NaT                 NaT    16     Foothill
# 852946        231210064    2023-12-04 2023-12-04 16:30:00    12  77th Street
# 852947        230115220    2023-02-07 2023-01-07 00:01:00     1      Central
# 852948        230906458    2023-05-03 2023-05-03 09:00:00     9     Van Nuys
# 852949        230319786    2023-10-11 2023-09-11 23:00:00     3    Southwest
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852950 entries, 0 to 852949
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   division_number      852950 non-null  int64
#  1   date_reported        341741 non-null  datetime64[ns]
#  2   date_occurred        350403 non-null  datetime64[ns]
#  3   area                 852950 non-null  int64
#  4   area_name            852950 non-null  object
#  5   reporting_district   852950 non-null  int64
#  6   part                 852950 non-null  int64
#  7   crime_code           852950 non-null  int64
#  8   crime_description    852950 non-null  object
#  9   victim_age           852950 non-null  int64
#  10  victim_sex           740344 non-null  object
#  11  victim_descent       740336 non-null  object
#  12  premise_code         852940 non-null  float64
#  13  premise_description  852432 non-null  object
# ...

# %%
df.describe(include=['float64','int64'])
# Out:
#        division_number           area  reporting_district           part  \
# count     8.529500e+05  852950.000000       852950.000000  852950.000000
# mean      2.166969e+08      10.707354         1117.165490       1.412575
# std       1.100081e+07       6.097178          609.716073       0.492298
# min       8.170000e+02       1.000000          101.000000       1.000000
# 25%       2.102184e+08       6.000000          615.000000       1.000000
# 50%       2.202184e+08      11.000000         1141.000000       1.000000
# 75%       2.301094e+08      16.000000         1617.000000       2.000000
# max       2.399306e+08      21.000000         2199.000000       2.000000
#
#           crime_code     victim_age   premise_code    weapon_code  \
# count  852950.000000  852950.000000  852940.000000  296748.000000
# mean      500.746338      29.742191     305.974292     363.225141
# std       207.705242      21.799470     216.950442     123.685519
# ...

# %%
df['victim_age'].value_counts()
# Out:
# victim_age
#  0      211842
#  30      19421
#  35      19008
#  31      18603
#  29      18552
#          ...
#  97         63
# -1          60
# -2          13
#  120         1
# -3           1
# Name: count, Length: 103, dtype: int64

# %%
df_age=df[df['victim_age']>0]

# %%
df_age['victim_age'].value_counts()
# Out:
# victim_age
# 30     19421
# 35     19008
# 31     18603
# 29     18552
# 28     18266
#        ...
# 95        89
# 96        88
# 98        67
# 97        63
# 120        1
# Name: count, Length: 99, dtype: int64

# %%
df['year'] = df['date_occurred'].dt.year
df['month'] = df['date_occurred'].dt.month

# %%
df.sort_values(by = 'date_reported')
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 2384          200304048    2020-01-01 2020-01-01 16:00:00     3    Southwest
# 155399        201604040    2020-01-01 2020-01-01 18:00:00    16     Foothill
# 108586        202004041    2020-01-01 2020-01-01 05:30:00    20      Olympic
# 4435          200504019    2020-01-01 2020-01-01 10:00:00     5       Harbor
# 193290        201704102    2020-01-01 2020-01-01 08:15:00    17   Devonshire
# ...                 ...           ...                 ...   ...          ...
# 852937        231609172           NaT                 NaT    16     Foothill
# 852938        230914386           NaT                 NaT     9     Van Nuys
# 852942        231510379           NaT                 NaT    15  N Hollywood
# 852944        231604807           NaT                 NaT    16     Foothill
# 852945        231606525           NaT                 NaT    16     Foothill
#
# ...

# %% [markdown]
# # Feature Understanding

# %%
df['month'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='month'>
